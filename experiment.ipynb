# %%
# !git clone https://github.com/gbao23127157/Final_ComputerVision_PETA.git
# Out:
# Cloning into 'Final_ComputerVision_PETA'...
# remote: Enumerating objects: 1864, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 1864 (delta 5), reused 7 (delta 3), pack-reused 1850 (from 3)
# Receiving objects: 100% (1864/1864), 390.32 MiB | 32.37 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# Updating files: 100% (1627/1627), done.

# %%
# %cd Final_ComputerVision_PETA/Source
# Out:
# /kaggle/working/Final_ComputerVision_PETA/Source

# %%
# !python train.py --mode baseline
# Out:
# 2026-04-17 15:57:23 - INFO - Train model: BASELINE
# 2026-04-17 15:57:23 - INFO - Sử dụng folder features: ./data/features/resnet
# 2026-04-17 15:57:24 - INFO - Dữ liệu: Train: 643 albums
# 2026-04-17 15:57:28 - INFO - --- Epoch 1/30 ---
# 2026-04-17 15:57:30 - INFO - Train - Loss: 1.4982 | Accuracy: 0.6252 | mAP: 0.6876
# 2026-04-17 15:57:30 - INFO - Valid - Loss: 1.2376 | Accuracy: 0.7329 | mAP: 0.8884
# 2026-04-17 15:57:30 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 15:57:30 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.7329 tại ./weights/baseline_weights.pth
# 2026-04-17 15:57:30 - INFO - --- Epoch 2/30 ---
# 2026-04-17 15:57:31 - INFO - Train - Loss: 1.0602 | Accuracy: 0.8072 | mAP: 0.8776
# 2026-04-17 15:57:31 - INFO - Valid - Loss: 1.1145 | Accuracy: 0.7702 | mAP: 0.8814
# 2026-04-17 15:57:31 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 15:57:31 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.7702 tại ./weights/baseline_weights.pth
# ...

# %%
# !python train.py --mode peta_base
# Out:
# 2026-04-17 15:58:07 - INFO - Train model: PETA_BASE
# 2026-04-17 15:58:08 - INFO - Sử dụng folder features: ./data/features/resnet
# 2026-04-17 15:58:08 - INFO - Dữ liệu: Train: 643 albums
# 2026-04-17 15:58:09 - INFO - --- Epoch 1/30 ---
# 2026-04-17 15:58:14 - INFO - Train - Loss: 2.1809 | Accuracy: 0.3110 | mAP: 0.3283
# 2026-04-17 15:58:15 - INFO - Valid - Loss: 1.6863 | Accuracy: 0.6708 | mAP: 0.8236
# 2026-04-17 15:58:15 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 15:58:15 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.6708 tại ./weights/peta_base_weights.pth
# 2026-04-17 15:58:15 - INFO - --- Epoch 2/30 ---
# 2026-04-17 15:58:19 - INFO - Train - Loss: 1.5151 | Accuracy: 0.5910 | mAP: 0.6552
# 2026-04-17 15:58:20 - INFO - Valid - Loss: 2.0384 | Accuracy: 0.6273 | mAP: 0.8338
# 2026-04-17 15:58:20 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 15:58:20 - INFO - --- Epoch 3/30 ---
# ...

# %%
# !python train.py --mode peta_clip
# Out:
# 2026-04-17 16:00:50 - INFO - Train model: PETA_CLIP
# 2026-04-17 16:00:50 - INFO - Sử dụng folder features: ./data/features/clip
# 2026-04-17 16:00:50 - INFO - Dữ liệu: Train: 643 albums
# 2026-04-17 16:00:51 - INFO - --- Epoch 1/30 ---
# 2026-04-17 16:00:53 - INFO - Train - Loss: 2.3605 | Accuracy: 0.2271 | mAP: 0.2390
# 2026-04-17 16:00:53 - INFO - Valid - Loss: 1.4992 | Accuracy: 0.5404 | mAP: 0.8522
# 2026-04-17 16:00:53 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 16:00:53 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.5404 tại ./weights/peta_clip_weights.pth
# 2026-04-17 16:00:53 - INFO - --- Epoch 2/30 ---
# 2026-04-17 16:00:54 - INFO - Train - Loss: 1.6804 | Accuracy: 0.5054 | mAP: 0.5576
# 2026-04-17 16:00:54 - INFO - Valid - Loss: 2.3815 | Accuracy: 0.4845 | mAP: 0.7461
# 2026-04-17 16:00:54 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 16:00:54 - INFO - --- Epoch 3/30 ---
# ...

# %%
# !python train.py --mode peta_cross
# Out:
# 2026-04-17 16:01:27 - INFO - Train model: PETA_CROSS
# 2026-04-17 16:01:27 - INFO - Sử dụng folder features: ./data/features/clip
# 2026-04-17 16:01:28 - INFO - Dữ liệu: Train: 643 albums
# 2026-04-17 16:01:29 - INFO - --- Epoch 1/30 ---
# 2026-04-17 16:01:30 - INFO - Train - Loss: 2.5793 | Accuracy: 0.1524 | mAP: 0.1535
# 2026-04-17 16:01:30 - INFO - Valid - Loss: 1.7934 | Accuracy: 0.5031 | mAP: 0.7896
# 2026-04-17 16:01:30 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 16:01:30 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.5031 tại ./weights/peta_cross_weights.pth
# 2026-04-17 16:01:30 - INFO - --- Epoch 2/30 ---
# 2026-04-17 16:01:31 - INFO - Train - Loss: 2.0356 | Accuracy: 0.3872 | mAP: 0.3967
# 2026-04-17 16:01:31 - INFO - Valid - Loss: 1.7998 | Accuracy: 0.5280 | mAP: 0.8183
# 2026-04-17 16:01:31 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-17 16:01:31 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.5280 tại ./weights/peta_cross_weights.pth
# ...

# %%
# !python evaluate.py --mode baseline
# Out:
# ...
#  Test: BASELINE
# ...
# -> Thư mục dữ liệu: ./data/features/resnet
# -> Đã tải thành công mô hình: ./weights/baseline_weights.pth
#    Lần 1 | Accuracy: 86.96% | mAP: 91.73%
#    Lần 2 | Accuracy: 88.82% | mAP: 92.39%
#    Lần 3 | Accuracy: 86.34% | mAP: 92.03%
#    Lần 4 | Accuracy: 86.34% | mAP: 92.18%
#    Lần 5 | Accuracy: 84.47% | mAP: 91.66%
#
# ...
#  BÁO CÁO KẾT QUẢ: BASELINE (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 86.58% ± 1.39%
#   mAP      : 92.00% ± 0.27%
# ...

# %%
# !python evaluate.py --mode peta_base
# Out:
# ...
#  Test: PETA_BASE
# ...
# -> Thư mục dữ liệu: ./data/features/resnet
# -> Đã tải thành công mô hình: ./weights/peta_base_weights.pth
#    Lần 1 | Accuracy: 90.06% | mAP: 95.04%
#    Lần 2 | Accuracy: 92.55% | mAP: 95.76%
#    Lần 3 | Accuracy: 89.44% | mAP: 93.92%
#    Lần 4 | Accuracy: 88.82% | mAP: 94.46%
#    Lần 5 | Accuracy: 90.68% | mAP: 95.59%
#
# ...
#  BÁO CÁO KẾT QUẢ: PETA_BASE (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 90.31% ± 1.28%
#   mAP      : 94.95% ± 0.69%
# ...

# %%
# !python evaluate.py --mode peta_clip
# Out:
# ...
#  Test: PETA_CLIP
# ...
# -> Thư mục dữ liệu: ./data/features/clip
# -> Đã tải thành công mô hình: ./weights/peta_clip_weights.pth
#    Lần 1 | Accuracy: 91.93% | mAP: 97.17%
#    Lần 2 | Accuracy: 91.30% | mAP: 96.09%
#    Lần 3 | Accuracy: 93.17% | mAP: 96.71%
#    Lần 4 | Accuracy: 92.55% | mAP: 96.57%
#    Lần 5 | Accuracy: 91.93% | mAP: 96.88%
#
# ...
#  BÁO CÁO KẾT QUẢ: PETA_CLIP (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 92.17% ± 0.63%
#   mAP      : 96.68% ± 0.36%
# ...

# %%
# !python evaluate.py --mode peta_cross
# Out:
# ...
#  Test: PETA_CROSS
# ...
# -> Thư mục dữ liệu: ./data/features/clip
# -> Đã tải thành công mô hình: ./weights/peta_cross_weights.pth
#    Lần 1 | Accuracy: 91.93% | mAP: 97.88%
#    Lần 2 | Accuracy: 92.55% | mAP: 97.86%
#    Lần 3 | Accuracy: 91.30% | mAP: 97.12%
#    Lần 4 | Accuracy: 91.93% | mAP: 97.40%
#    Lần 5 | Accuracy: 92.55% | mAP: 97.46%
#
# ...
#  BÁO CÁO KẾT QUẢ: PETA_CROSS (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 92.05% ± 0.46%
#   mAP      : 97.54% ± 0.29%
# ...
