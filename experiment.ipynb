# %%
# !git clone https://github.com/gbao23127157/Final_ComputerVision_PETA.git
# Out:
# Cloning into 'Final_ComputerVision_PETA'...
# remote: Enumerating objects: 989, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 989 (delta 41), reused 48 (delta 27), pack-reused 921 (from 2)
# Receiving objects: 100% (989/989), 277.84 MiB | 33.50 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# Updating files: 100% (841/841), done.

# %%
# %cd Final_ComputerVision_PETA/Source
# Out:
# /kaggle/working/Final_ComputerVision_PETA/Source

# %%
# !mkdir -p ../Release

# %%
# !python train.py
# Out:
# 2026-04-07 17:11:06 - INFO - Khởi động huấn luyện PETA
# 2026-04-07 17:11:06 - INFO - Dữ liệu ép chuẩn: Train: 643 albums | Test: 161 albums
# 2026-04-07 17:11:08 - INFO - --- Epoch 1/30 ---
# 2026-04-07 17:11:13 - INFO - Train - Loss: 2.5722 | Accuracy: 0.1742 | mAP: 0.1489
# 2026-04-07 17:11:14 - INFO - Test - Loss: 2.0379 | Accuracy: 0.4348 | mAP: 0.6289
# 2026-04-07 17:11:14 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-07 17:11:14 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.4348 tại ../Release/best_peta_model.pth
# 2026-04-07 17:11:14 - INFO - --- Epoch 2/30 ---
# 2026-04-07 17:11:18 - INFO - Train - Loss: 2.2798 | Accuracy: 0.2939 | mAP: 0.3074
# 2026-04-07 17:11:19 - INFO - Test - Loss: 1.9327 | Accuracy: 0.6273 | mAP: 0.7470
# 2026-04-07 17:11:19 - INFO - Learning Rate hiện tại: 0.010000
# 2026-04-07 17:11:20 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.6273 tại ../Release/best_peta_model.pth
# 2026-04-07 17:11:20 - INFO - --- Epoch 3/30 ---
# ...

# %%
# !python evaluate.py
# Out:
# Đang chuẩn bị dữ liệu Test...
# -> Đã tải thành công file trọng số best_peta_model.pth!
#
# BẮT ĐẦU ĐÁNH GIÁ 5 LẦN
#
#    Hoàn thành Lần 1 | Accuracy: 90.68% | mAP: 94.53%
#    Hoàn thành Lần 2 | Accuracy: 88.82% | mAP: 94.32%
#    Hoàn thành Lần 3 | Accuracy: 89.44% | mAP: 94.52%
#    Hoàn thành Lần 4 | Accuracy: 89.44% | mAP: 94.26%
#    Hoàn thành Lần 5 | Accuracy: 88.20% | mAP: 93.98%
#
# ...
#  BÁO CÁO KẾT QUẢ PETA (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 89.32% ± 0.82%
#   mAP      : 94.32% ± 0.20%
# ...

# %%
# !python train_baseline.py
# Out:
# 2026-04-07 17:14:15 - INFO - --- Epoch 1/20 ---
# 2026-04-07 17:14:16 - INFO - Train - Loss: 1.9742 | Accuracy: 0.4241 | mAP: 0.4821
# 2026-04-07 17:14:16 - INFO - Val - Loss: 1.7773 | Accuracy: 0.7209 | mAP: 0.7735
# 2026-04-07 17:14:16 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.7209 tại ../Release/best_baseline_model.pth
# 2026-04-07 17:14:16 - INFO - --- Epoch 2/20 ---
# 2026-04-07 17:14:17 - INFO - Train - Loss: 1.0317 | Accuracy: 0.8054 | mAP: 0.8764
# 2026-04-07 17:14:17 - INFO - Val - Loss: 0.9390 | Accuracy: 0.8217 | mAP: 0.8602
# 2026-04-07 17:14:17 - INFO - -> Đã lưu mô hình tốt nhất với Accuracy: 0.8217 tại ../Release/best_baseline_model.pth
# 2026-04-07 17:14:17 - INFO - --- Epoch 3/20 ---
# 2026-04-07 17:14:17 - INFO - Train - Loss: 0.7654 | Accuracy: 0.8638 | mAP: 0.9168
# 2026-04-07 17:14:17 - INFO - Val - Loss: 0.7910 | Accuracy: 0.8217 | mAP: 0.8684
# 2026-04-07 17:14:17 - INFO - --- Epoch 4/20 ---
# ...

# %%
# !python evaluate_baseline.py
# Out:
# Đang chuẩn bị dữ liệu Test...
# -> Đã tải thành công file trọng số ../Release/best_baseline_model.pth!
#
# BẮT ĐẦU ĐÁNH GIÁ 5 LẦN...
#
#    Hoàn thành Lần 1 | Accuracy: 86.96% | mAP: 92.54%
#    Hoàn thành Lần 2 | Accuracy: 86.96% | mAP: 93.55%
#    Hoàn thành Lần 3 | Accuracy: 85.09% | mAP: 92.73%
#    Hoàn thành Lần 4 | Accuracy: 85.09% | mAP: 93.07%
#    Hoàn thành Lần 5 | Accuracy: 85.71% | mAP: 93.05%
#
# ...
#  BÁO CÁO KẾT QUẢ BASELINE (TRUNG BÌNH SAU 5 LẦN)
# ...
#   Accuracy : 85.96% ± 0.84%
#   mAP      : 92.99% ± 0.35%
# ...
